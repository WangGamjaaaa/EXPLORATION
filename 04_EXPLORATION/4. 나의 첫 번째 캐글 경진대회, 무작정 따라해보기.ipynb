# %% [markdown]
# # 목차
# <hr/>

# %% [markdown]
# <ol>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;">필요한 모듈 불러오기</i>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 데이터, 평가 기준 살펴보기</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 대회 소개, 평가 기준 살펴보기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 데이터 살펴보기</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 데이터 전처리</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 데이터 불러오기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> date 칼럼 정리하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> id 삭제하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">4. </span> 데이터 확인하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">5. </span> 학습 데이터에서 target값 분리하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">6. </span> train, test데이터 분리하기</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 3</span> : 모델 개요</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 사용한 모델</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> CatBoostRegressor란?</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> 모델을 선택한 이유?</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 모델 학습하기</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 모델 학습하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 모델의 특성 중요도를 시각화하기 - (1) feature_importances_</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> 모델의 특성 중요도를 시각화하기 - (2) Permutation Feature Importance</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">4. </span> RMSE 출력해보기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">5. </span> test 데이터 predict하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">6. </span> 학습 데이터의 데이터 예측 시각화해보기</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : test.csv에 실제로 적용해보기</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> test 데이터 준비하기
#             </li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> test 데이터 예측하기</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : 제출하기</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> submission 파일 만들기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 캐글에 제출하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> 결과</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;">회고</i>
# </ol>

# %% [markdown]
# # 필요한 모듈 불러오기

# %%
import warnings
warnings.filterwarnings("ignore")

import os

import eli5
import lightgbm          as lgb
import matplotlib.pyplot as plt
import missingno         as msno
import numpy             as np
import pandas            as pd
import seaborn           as sns
import xgboost           as xgb


from os.path                 import join
from sklearn.ensemble        import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_validate, cross_val_score, train_test_split
from sklearn.metrics         import mean_squared_error
from scipy.stats             import uniform, randint
from sklearn.model_selection import RandomizedSearchCV
from eli5.sklearn            import PermutationImportance
from catboost                import CatBoostRegressor

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# <div style = "height: 50px;"><div/>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 데이터, 평가 기준 살펴보기

# %% [markdown]
# [참여할 캐글 대회](https://www.kaggle.com/c/2019-2nd-ml-month-with-kakr)

# %% [markdown]
# ## 1. 대회 소개, 평가 기준 살펴보기
# <hr/>

# %% [markdown]
# ### (1)Description, 대회 소개

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">데이터는 20개의 변수를 가지고 있으며, 어떤 조건을 가진 집의 가격이 높고 낮은지를 예측하는 모델을 만드는 것이 목표이다.<br/>
# 따라서, 이 문제는 집값을 예측하는 <span style = 'background-color:#fff5b1; padding:0.2px;'>회귀</span> 문제이다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### (2) Evaluation, 점수 평가 기준
# <p style= "font-size:15px; line-height:24px;">
# 평가 방식은 <span style = 'background-color:#fff5b1; padding:0.2px;'>RMSE (Root Mean Squared Error)</span> 이다. $${\sqrt{ {1 \over N} \sum{(yt - y{pr})}^2}} $$</p>

# %% [markdown]
# <div style = "height: 50px;"><div/>

# %% [markdown]
# ## 2. 데이터 살펴보기
# <hr/>

# %% [markdown]
# ### (1) 데이터 설명

# %% [markdown]
# <ul>
# 	<li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">train.csv</span> - 예측 모델을 만들기 위해 사용하는 학습 데이터이다. 집의 정보와 예측할 변수인 가격(Price) 변수를 가지고 있다.</li>
# 	<li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">test.csv</span> - 학습셋으로 만든 모델을 가지고 예측할 가격(Price) 변수를 제외한 집의 정보가 담긴 테스트 데이터이다.</li>
# 	<li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sample_submission.csv</span> - 제출시 사용할 수 있는 예시 submission.csv 파일</li>
# </ul>

# %% [markdown]
# #### Data fields

# %% [markdown]
# <ul>
# 	<li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">ID : </span> 집을 구분하는 번호</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">date : </span> 집을 구매한 날짜</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">price : </span> 집의 가격(Target variable)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">bedrooms : </span> 침실의 수</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">bathrooms : </span> 화장실의 수</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_living : </span> 주거 공간의 평방 피트(면적)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_lot : </span> 부지의 평방 피트(면적)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">floors : </span> 집의 층 수</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">waterfront : </span> 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">view : </span> 집이 얼마나 좋아 보이는지의 정도</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">condition : </span> 집의 전반적인 상태</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">grade : </span> King County grading 시스템 기준으로 매긴 집의 등급</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_above : </span> 지하실을 제외한 평방 피트(면적)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_basement : </span> 지하실의 평방 피트(면적)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">yr_built : </span> 지어진 년도</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">yr_renovated : </span> 집을 재건축한 년도</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">zipcode : </span> 우편번호</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">lat : </span> 위도</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">long : </span> 경도</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_living15 : </span> 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)</li>
#     <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">sqft_lot15 : </span> 2015년 기준 부지의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)</li>
# </ul>

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">우리가 예측해야 하는 컬럼은 price(집의 가격)이다. <br/>따라서 <span style = 'background-color:#fff5b1; padding:0.2px;'>타겟값은 'price'이다.</span></p>

# %% [markdown]
# <div style = "height: 25px;"><div/>

# %% [markdown]
# ### (2) 목표

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">train.csv를 활용해서 데이터를 전처리하여 모델을 학습시킨 후, <br/>test.csv 파일의 데이터에 대해 price를 예측한 후 sample_submission.csv의 형식에 맞는 형태로 캐글에 제출을 할 것이다.</p>

# %% [markdown]
# <div style = "height: 50px;"><div/>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 데이터 전처리

# %% [markdown]
# ## 1. 데이터 불러오기
# <hr/>

# %%
train = pd.read_csv('data_2/train.csv')
test = pd.read_csv('data_2/test.csv')

# %%
train
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 0          0  20141013T000000   221900.0         3       1.00         1180
# 1          1  20150225T000000   180000.0         2       1.00          770
# 2          2  20150218T000000   510000.0         3       2.00         1680
# 3          3  20140627T000000   257500.0         3       2.25         1715
# 4          4  20150115T000000   291850.0         3       1.50         1060
# ...      ...              ...        ...       ...        ...          ...
# 15030  15030  20141014T000000   610685.0         4       2.50         2520
# 15031  15031  20150326T000000  1007500.0         4       3.50         3510
# 15032  15032  20140521T000000   360000.0         3       2.50         1530
# 15033  15033  20150223T000000   400000.0         4       2.50         2310
# 15034  15034  20141015T000000   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0           0     0  ...      7        1180
# 1         10000     1.0           0     0  ...      6         770
# 2          8080     1.0           0     0  ...      8        1680
# 3          6819     2.0           0     0  ...      7        1715
# 4          9711     1.0           0     0  ...      7        1060
# ...         ...     ...         ...   ...  ...    ...         ...
# 15030      6023     2.0           0     0  ...      9        2520
# 15031      7200     2.0           0     0  ...      9        2600
# 15032      1131     3.0           0     0  ...      8        1530
# 15033      5813     2.0           0     0  ...      8        2310
# 15034      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                  0      1955             0    98178  47.5112 -122.257
# 1                  0      1933             0    98028  47.7379 -122.233
# 2                  0      1987             0    98074  47.6168 -122.045
# 3                  0      1995             0    98003  47.3097 -122.327
# 4                  0      1963             0    98198  47.4095 -122.315
# ...              ...       ...           ...      ...      ...      ...
# 15030              0      2014             0    98056  47.5137 -122.167
# 15031            910      2009             0    98136  47.5537 -122.398
# 15032              0      2009             0    98103  47.6993 -122.346
# 15033              0      2014             0    98146  47.5107 -122.362
# 15034              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               2720        8062
# 2               1800        7503
# 3               2238        6819
# 4               1650        9711
# ...              ...         ...
# 15030           2520        6023
# 15031           2050        6200
# 15032           1530        1509
# 15033           1830        7200
# 15034           1020        1357
#
# [15035 rows x 21 columns]

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 2. date 칼럼 정리하기
# <hr/>

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">20141013T000000 형식의 데이터를 연/월 데이터만 사용하기 위해 <span style = 'background-color:#fff5b1; padding:0.2px;'>str(x[:6]) 으로 연/월까지 자른다.</span></p>

# %%
# date 칼럼 정리
train['date'] = train['date'].apply(lambda x : str(x[:6])).astype(int)
train.head()
# Out:
#    id    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   0  201410  221900.0         3       1.00         1180      5650     1.0
# 1   1  201502  180000.0         2       1.00          770     10000     1.0
# 2   2  201502  510000.0         3       2.00         1680      8080     1.0
# 3   3  201406  257500.0         3       2.25         1715      6819     2.0
# 4   4  201501  291850.0         3       1.50         1060      9711     1.0
#
#    waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0  ...      7        1180              0      1955
# 1           0     0  ...      6         770              0      1933
# 2           0     0  ...      8        1680              0      1987
# 3           0     0  ...      7        1715              0      1995
# 4           0     0  ...      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1             0    98028  47.7379 -122.233           2720        8062
# 2             0    98074  47.6168 -122.045           1800        7503
# 3             0    98003  47.3097 -122.327           2238        6819
# 4             0    98198  47.4095 -122.315           1650        9711
#
# [5 rows x 21 columns]

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 3. id 삭제하기
# <hr/>

# %%
# id 삭제
del train['id']
print(train.columns)
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 4. 데이터 확인하기
# <hr/>

# %% [markdown]
# ### (1) 데이터 상관계수 확인하기

# %%
train.corr()
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date           1.000000  0.007717 -0.002696  -0.022810    -0.022119  0.007500
# price          0.007717  1.000000  0.323672   0.525479     0.702899  0.096793
# bedrooms      -0.002696  0.323672  1.000000   0.530548     0.596974  0.033475
# bathrooms     -0.022810  0.525479  0.530548   1.000000     0.755853  0.089308
# sqft_living   -0.022119  0.702899  0.596974   0.755853     1.000000  0.176500
# sqft_lot       0.007500  0.096793  0.033475   0.089308     0.176500  1.000000
# floors        -0.020891  0.262588  0.189532   0.508649     0.363193  0.001535
# waterfront    -0.001742  0.265738 -0.004819   0.075452     0.108137  0.025584
# view           0.013986  0.400806  0.085703   0.187488     0.282821  0.080441
# condition     -0.047028  0.039740  0.034885  -0.125907    -0.054213 -0.002099
# grade         -0.023233  0.667211  0.375286   0.666278     0.762543  0.119906
# sqft_above    -0.019422  0.608577  0.494867   0.688255     0.878736  0.186242
# sqft_basement -0.009627  0.322218  0.315183   0.282642     0.434017  0.017818
# yr_built       0.004517  0.047290  0.158799   0.503964     0.315927  0.058686
# yr_renovated  -0.019625  0.140808  0.022729   0.065423     0.064893 -0.001451
# zipcode       -0.000763 -0.051498 -0.162081  -0.207500    -0.200745 -0.127709
# lat           -0.031683  0.301604 -0.011190   0.018110     0.051609 -0.082234
# long           0.002894  0.023547  0.135802   0.227669     0.245429  0.227451
# sqft_living15 -0.014327  0.586419  0.407394   0.573541     0.760271  0.147562
# sqft_lot15     0.003511  0.086384  0.027242   0.088120     0.184176  0.728458
#
#                  floors  waterfront      view  condition     grade  \
# date          -0.020891   -0.001742  0.013986  -0.047028 -0.023233
# price          0.262588    0.265738  0.400806   0.039740  0.667211
# bedrooms       0.189532   -0.004819  0.085703   0.034885  0.375286
# bathrooms      0.508649    0.075452  0.187488  -0.125907  0.666278
# sqft_living    0.363193    0.108137  0.282821  -0.054213  0.762543
# sqft_lot       0.001535    0.025584  0.080441  -0.002099  0.119906
# floors         1.000000    0.031159  0.034511  -0.261016  0.462598
# waterfront     0.031159    1.000000  0.389669   0.011613  0.088061
# view           0.034511    0.389669  1.000000   0.045255  0.247924
# condition     -0.261016    0.011613  0.045255   1.000000 -0.143599
# grade          0.462598    0.088061  0.247924  -0.143599  1.000000
# sqft_above     0.529476    0.081968  0.172693  -0.152856  0.759240
# sqft_basement -0.239350    0.071576  0.265880   0.175064  0.162657
# yr_built       0.490436   -0.026523 -0.061670  -0.366590  0.440608
# yr_renovated   0.009752    0.104168  0.107605  -0.062342  0.030155
# zipcode       -0.059107    0.028632  0.089247   0.001106 -0.186541
# lat            0.049004   -0.014772  0.005285  -0.015974  0.112319
# long           0.126983   -0.037922 -0.073151  -0.110742  0.202130
# sqft_living15  0.287125    0.091810  0.278267  -0.091407  0.715321
# sqft_lot15    -0.010287    0.028255  0.076501  -0.003873  0.119734
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# date            -0.019422      -0.009627  0.004517     -0.019625 -0.000763
# price            0.608577       0.322218  0.047290      0.140808 -0.051498
# bedrooms         0.494867       0.315183  0.158799      0.022729 -0.162081
# bathrooms        0.688255       0.282642  0.503964      0.065423 -0.207500
# sqft_living      0.878736       0.434017  0.315927      0.064893 -0.200745
# sqft_lot         0.186242       0.017818  0.058686     -0.001451 -0.127709
# floors           0.529476      -0.239350  0.490436      0.009752 -0.059107
# waterfront       0.081968       0.071576 -0.026523      0.104168  0.028632
# view             0.172693       0.265880 -0.061670      0.107605  0.089247
# condition       -0.152856       0.175064 -0.366590     -0.062342  0.001106
# grade            0.759240       0.162657  0.440608      0.030155 -0.186541
# sqft_above       1.000000      -0.048623  0.422431      0.031441 -0.258474
# sqft_basement   -0.048623       1.000000 -0.136214      0.076452  0.067782
# yr_built         0.422431      -0.136214  1.000000     -0.215760 -0.354280
# yr_renovated     0.031441       0.076452 -0.215760      1.000000  0.068307
# zipcode         -0.258474       0.067782 -0.354280      0.068307  1.000000
# lat              0.001074       0.105969 -0.156563      0.034844  0.261312
# long             0.347226      -0.141792  0.414565     -0.070134 -0.563455
# sqft_living15    0.737795       0.198380  0.324221      0.007995 -0.274176
# sqft_lot15       0.194226       0.018813  0.076009     -0.000348 -0.145710
#
#                     lat      long  sqft_living15  sqft_lot15
# date          -0.031683  0.002894      -0.014327    0.003511
# price          0.301604  0.023547       0.586419    0.086384
# bedrooms      -0.011190  0.135802       0.407394    0.027242
# bathrooms      0.018110  0.227669       0.573541    0.088120
# sqft_living    0.051609  0.245429       0.760271    0.184176
# sqft_lot      -0.082234  0.227451       0.147562    0.728458
# floors         0.049004  0.126983       0.287125   -0.010287
# waterfront    -0.014772 -0.037922       0.091810    0.028255
# view           0.005285 -0.073151       0.278267    0.076501
# condition     -0.015974 -0.110742      -0.091407   -0.003873
# grade          0.112319  0.202130       0.715321    0.119734
# sqft_above     0.001074  0.347226       0.737795    0.194226
# sqft_basement  0.105969 -0.141792       0.198380    0.018813
# yr_built      -0.156563  0.414565       0.324221    0.076009
# yr_renovated   0.034844 -0.070134       0.007995   -0.000348
# zipcode        0.261312 -0.563455      -0.274176   -0.145710
# lat            1.000000 -0.133460       0.048924   -0.081725
# long          -0.133460  1.000000       0.333673    0.256201
# sqft_living15  0.048924  0.333673       1.000000    0.183599
# sqft_lot15    -0.081725  0.256201       0.183599    1.000000

# %% [markdown]
# #### 시각화

# %%
df = train.corr()
# 그림 사이즈 지정
fig, ax = plt.subplots(figsize = (15,10))

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(df, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask = mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths = 3,  # 경계면 실선으로 구분하기
            cbar_kws = {"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">상관계수를 확인해본 결과, 모든 특성이 price(target)에 대해 양의 상관 관계가 있다.<br/>
# 보통 ±0.2로는 상관관계가 거의 없다고는하나, 아예 없는 것(0 / NAN)은 아니므로 특성을 제거하지 않고 학습시킬 것이다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### (2) 데이터 분포 시각화하기

# %%
# 데이터 분포 확인하기
fig, ax = plt.subplots(10, 2, figsize = (10, 30))
plt.tight_layout(pad = 3, h_pad = 8)

# id 변수(count == 0인 경우)는 제외하고 분포를 확인함
count = 1
columns = train.columns
for row in range(10):
    for col in range(2):
        sns.kdeplot(data=train[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize = 15)
        count += 1
        if count == 20:
            break

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">price, bedrooms, sqft_living, sqft_lot, sqft_above, sqft_basement 변수가 한쪽으로 치우친 것을 확인할 수 있었다.<br/>
# 그러나, 데이터를 따로 전처리 하지 않고 진행해볼 예정이다.<br/>
# 이유는, 트리모델은 각 특성이 개별적으로 처리되어 데이터를 분할하는 데 데이터 스케일의 영향을 받지 않으므로 결정 트리에서는 특성의 정규화나 표준화 같은 전처리 과정이 필요 없다.<br/>
# catboost 또한 트리를 생성하기 때문에 데이터 전처리를 하지 않아도 결과가 좋을 것이라고 예상한다.</p>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 5. 학습 데이터에서 target값 분리하기
# <hr/>

# %% [markdown]
# ### 삭제 전, 타겟값 y에 저장하기

# %%
y = train['price']

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### 학습 데이터에서 target(price)값 삭제

# %%
del train['price']

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### x값 지정하기

# %%
x = train

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 6. train, test데이터 분리하기
# <hr/>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 모델 개요

# %% [markdown]
# ## 1. 사용한 모델
# <hr/>
# <p style= "font-size:20px;">CatBoostRegressor</p>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 2. CatBoostRegressor란?
# <hr/>

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">GBM(Gradient Boosting Machines) 알고리즘을 기반으로, <span style = 'background-color:#fff5b1; padding:0.2px;'>GBM의 단점을 개선하여 만들어진 알고리즘이다.</span></p>

# %% [markdown]
# - <span style = 'background-color:#fff5b1; padding:0.2px;'>과적합(overfitting)</span> 문제를 해결
# - GBM 계열의 알고리즘인 XGBoost, LightGBM보다 <span style = 'background-color:#fff5b1; padding:0.2px;'>학습속도가 빠르다.</span>
# - XGBoost, LightGBM이 하이퍼 파라미터에 따라 성능이 달라지는 문제가 있으나,<br/> 캣부스트는 이러한 문제를 해소하였다.
# - 모델을 맞출 때 시각화를 할 수 있는 파라미터가 있어 <span style = 'background-color:#fff5b1; padding:0.2px;'>시각화가 편리</span>하다.

# %% [markdown]
# ### GBM(Gradient Boosting Machines)이란?

# %% [markdown]
# - 주어진 데이터에 대해 계속적으로 학습(fit)하여 모델을 만든 후, 다른 데이터를 예측(predict)함으로서, 간차를 줄여나가는 방식이다.
# - 최초의 데이터 이후는 계산한 잔차에 포커스를 맞추어 학습하므로, 새로운 데이터에 대한 예측이 떨어질 수 있다. (overfitting을 유발할 가능성이 높다)

# %% [markdown]
# ### 비교하기

# %% [markdown]
# <table style="float:left; font-size:15px; width:80%; border:0.2px solid">
#     <th style = "text-align:center; width:33.33%; border:0.2px solid">LightGBM</th>
#     <th style = "text-align:center; width:33.33%; border:0.2px solid">XGBoost</th>
#     <th style = "text-align:center; width:33.33%; border:0.2px solid">Catboost</th>
#     <tr>
#         <td style = "text-align:center; width:33.33%; border:0.2px solid">DFS(깊이 우선 탐색)<br/> 트리를 먼저 깊게 형성한다.</td>
#         <td style = "text-align:center; width:33.33%; border:0.2px solid">BFS(너비 우선 탐색)<br/> 트리를 먼저 넓게 형성한다.</td>
#         <td style = "text-align:center; width:33.33%; border:0.2px solid">특성(feature)를 모두 동일하게<br/> 대칭적으로 트리를 형성하여<br/><span style = 'background-color:#fff5b1; padding:0.2px;'>예측 시간을 감소</span>시켰다.</td>
#     </tr>
# </table>

# %% [markdown]
# ### CatBoost의 파라미터

# %%
for key,value in moedel_cat.get_all_params().items(): print('{}, {}'.format(key,value))
# Out:
# nan_mode, Min
# eval_metric, RMSE
# iterations, 10000
# sampling_frequency, PerTree
# leaf_estimation_method, Newton
# grow_policy, SymmetricTree
# penalties_coefficient, 1
# boosting_type, Plain
# model_shrink_mode, Constant
# feature_border_type, GreedyLogSum
# bayesian_matrix_reg, 0.10000000149011612
# force_unit_auto_pair_weights, False
# l2_leaf_reg, 3
# random_strength, 1
# rsm, 1
# boost_from_average, True
# model_size_reg, 0.5
# pool_metainfo_options, {'tags': {}}
# subsample, 0.800000011920929
# use_best_model, False
# random_seed, 42
# depth, 6
# posterior_sampling, False
# border_count, 254
# classes_count, 0
# auto_class_weights, None
# sparse_features_conflict_fraction, 0
# leaf_estimation_backtracking, AnyImprovement
# best_model_min_trees, 1
# model_shrink_rate, 0
# min_data_in_leaf, 1
# loss_function, RMSE
# learning_rate, 0.009134000167250632
# score_function, Cosine
# task_type, CPU
# leaf_estimation_iterations, 1
# bootstrap_type, MVS
# max_leaves, 64

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 3. 모델을 선택한 이유?
# <hr/>

# %% [markdown]
# <p style= "font-size:15px; line-height:26px;">LightGBM와 XGBoost에 대해 알아보던 중, CatBoost를 같이 비교하는 글을 많이 접했습니다.<br/>
# 특히 XGBoost와 CatBoost는 같이 나오는 경우가 많아 읽어보았는데, LightGBM와 XGBoost는 모두 GBM 알고리즘 기반이며, 캣부스트는 GBM의 단점을 개선하여 만들어진 알고리즘이라 하여 사용하게 되었습니다.<br/><br/>
# 또한, LightGBM과 XGBoost는 하이퍼 파라미터에 민감하므로, 최적의 파라미터를 찾아야 성능이 좋지만, 캣부스트는 하이퍼 파라미터를 설정하지 않아도 모델의 성능이 우수하며, 하이퍼 파라미터를 설정하면 더욱 좋은 성능을 낼 수 있다는 것에 매력을 느꼈습니다.<br/><br/>
# 처음에는 캣부스트가 결측치가 많은 데이터에는 부적합한 모델이라 하여 걱정했지만, 캐글 데이터를 확인해본 결과, 결측치가 없어 모델이 잘 작동할 것이라 예측합니다.</p>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 4</span> : 모델 학습하기

# %% [markdown]
# ## 1. 모델 학습하기
# <hr/>

# %%
moedel_cat = CatBoostRegressor(random_state=42, iterations = 10000)

# %%
# 모델 학습 및, 시각화 하기
score_cat = moedel_cat.fit(x_train, y_train, verbose=False, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %% [markdown]
# <img src = "img/catboost_img.png">

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">Catboost에 plot = True를 주어 모델의 학습 과정을 그래프로 나타내어 확인할 수 있다.<br/>
# 그러나, 깃허브에서는 그래프가 출력이 되지 않는 현상이 발생하였으며, 해결 방법을 찾지 못하여 이미지로 대체할 것이다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ## 2. 모델의 특성 중요도를 시각화하기 - (1)  feature_importances_
# <hr/>

# %%
score_cat.feature_importances_
# Out:
# array([ 0.77840268,  0.26690384,  1.95533895, 17.6052155 ,  1.7728609 ,
#         0.36867031,  2.89302515,  2.77140325,  0.71539323, 13.81500654,
#         5.16626233,  1.11839057,  3.15376141,  0.73110215,  2.47450933,
#        26.07587933, 12.59571978,  4.8556861 ,  0.88646866])

# %%
sorted_idx = np.argsort(score_cat.feature_importances_)

# %%
def plot_feature_importance(model):
    n_features = x_train.shape[1]
    plt.barh(np.arange(n_features), sorted(model.feature_importances_), align="center")
    plt.yticks(np.arange(n_features), x_train.columns)
    plt.xlabel("Catboost Feature Importance")
    plt.ylabel("Feature")
    plt.ylim(-1, n_features)
    
plot_feature_importance(score_cat)

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">sqft_lot15, sqft_living15, long, lat, zipcode순으로 중요도가 높게 나왔다.<br/>그러나, 트리 모델은 지니 불순도를 이용하여 각 변수의 중요도를 계산하기 때문에 연속형 변수 또는 카테고리 개수가 매우 많은 변수들의 중요도를 부풀릴 수 있는 가능성이 있으므로, (과적합 가능성) Permutation Feature Importance를 같이 사용하여 비교할 것이다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ## 모델의 특성 중요도를 시각화하기 - (2)  Permutation Feature Importance
# <hr/>

# %% [markdown]
# #### Permutation Importance

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">모델의 훈련(fit)이 끝난 후 측정하며, <span style = 'background-color:#fff5b1; padding:0.2px;'>컬럼을 무작위로 섞은 뒤 정확도를 측정</span>하는 방식이다.<br/>위 작업을 모든 컬럼에 대해서 진행하며 모델이 예측에 크게 의존하는 열을 섞으면 정확도가 크게 떨어지지만, 연속형 변수의 중요도를 부풀리지 않는다. (과적합 X )</p>

# %%
perm = PermutationImportance(moedel_cat, random_state = 42).fit(x_test, y_test)

# %%
permu = eli5.show_weights(perm, feature_names = x_train.columns.tolist())
permu
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4574
#
#                     &plusmn; 0.0382
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1973
#
#                     &plusmn; 0.0071
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_living
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1604
#
#                     &plusmn; 0.0158
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 long
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1317
#
#                     &plusmn; 0.0075
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 grade
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0271
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_lot
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0254
#
#                     &plusmn; 0.0058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 waterfront
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0249
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 yr_built
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0228
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_living15
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0190
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 zipcode
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 view
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0176
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_above
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 condition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0049
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 date
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 yr_renovated
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sqft_lot15
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bathrooms
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0002
#
#             </td>

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">feature_importances_와 전혀 다른 결과가 나왔다.<br/>
# lat, sqft_living, long, grade, sqft_lot 순으로 중요도가 높은 것을 확인할 수 있었다.<br/>
# 그렇다는 것은, 모델이 과적합 되었을 수 있다는 것이므로, 테스트 데이터를 예측 한 후, RMSE값을 한번 확인을 해봐야 할 것 같다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ## 4. RMSE 출력해보기
# <hr/>

# %%
score_cat.best_score_
# Out:
# {'learn': {'RMSE': 52230.46937133446}}

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ## 5. test 데이터 predict하기
# <hr/>

# %%
cat_pred = score_cat.predict(x_test)

# %%
pd.DataFrame(cat_pred).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ## 6. 학습 데이터의 데이터 예측 시각화해보기
# <hr/>

# %%
plt.scatter(x_test['sqft_living15'], y_test)
plt.scatter(x_test['sqft_living15'], cat_pred)

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">그래프를 출력해보니, 예측값과 실제 값이 크게 차이가 나지 않는 것을 확인하였다.<br/>
# 훈련이 잘 되었다는 뜻이므로, 직접 테스트 데이터에 적용하고자 한다.</p>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : test.csv에 실제로 적용해보기

# %% [markdown]
# ## 1.  test 데이터 준비하기
# <hr/>

# %% [markdown]
# ### id 삭제하기

# %%
sub_id = test['id'] 
del test['id']
print(test.columns)
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### date 칼럼 정리하기

# %%
test['date'] = test['date'].apply(lambda i : i[:6]).astype(int)
test.head()
# Out:
#      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  201412         3       2.25         2570      7242     2.0           0
# 1  201412         4       3.00         1960      5000     1.0           0
# 2  201405         4       4.50         5420    101930     1.0           0
# 3  201504         3       1.00         1780      7470     1.0           0
# 4  201503         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        2170            400      1951          1991
# 1     0          5      7        1050            910      1965             0
# 2     0          3     11        3890           1530      2001             0
# 3     0          3      7        1050            730      1960             0
# 4     0          3      7        1890              0      2003             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98125  47.7210 -122.319           1690        7639
# 1    98136  47.5208 -122.393           1360        5000
# 2    98053  47.6561 -122.005           4760      101930
# 3    98146  47.5123 -122.337           1780        8113
# 4    98038  47.3684 -122.031           2390        7570

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 2. test 데이터 예측하기
# <hr/>

# %%
cat_pred = score_cat.predict(test)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : 제출하기

# %% [markdown]
# ## 1. submission 파일 만들기
# <hr/>

# %%
submission_path = join('data/sample_submission.csv')
submission = pd.read_csv(submission_path)
submission.head()
# Out:
#       id   price
# 0  15035  100000
# 1  15036  100000
# 2  15037  100000
# 3  15038  100000
# 4  15039  100000

# %%
submission['price'] = cat_pred
submission.head()
# Out:
#       id         price
# 0  15035  5.209230e+05
# 1  15036  4.895070e+05
# 2  15037  1.435201e+06
# 3  15038  3.071975e+05
# 4  15039  3.217872e+05

# %%
submission_csv_path = '{}/submission_{}_RMSLE_{}.csv'.format('data_2', 'cat', '0.164399')
submission.to_csv(submission_csv_path, index=False)
print(submission_csv_path)
# Out:
# data_2/submission_cat_RMSLE_0.164399.csv

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# ## 2. 캐글에 제출하기
# <hr/>

# %% [markdown]
# <img src = "img/kaggle.png">

# %% [markdown]
# ## 3. 결과
# <hr/>

# %% [markdown]
# <p style= "font-size:15px; line-height:24px;">제출한결과, 점수가 110000이하로 떨어진 것을 확인할 수 있었다.<br/>
# LightGBM와 XGBoost의 단점을 개선한 Catboost가 성능이 좋을 것이라고 예측했던 것이 맞았다.<br/>
# 또한, 모델이 과적합되었을 수도 있다고 생각한 것과는 달리, 성능이 괜찮게 나왔다.<br/>
# iterations로 트리의 최대 생성 개수를 늘릴 수록 성능이 좋아진 것을 확인할 수 있었다.<br/>
# 적당한 값을 찾으면 더욱 더 좋은 성능을 낼 수 있을 것이라 예측된다.</p>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 회고
# <hr/>

# %% [markdown]
# ### 실패 1

# %% [markdown]
# <p style= "font-size:16px; line-height:30px;">처음에는 'yr_renovated'이라는 변수를 년도가 아닌 재건축 여부로(int > bools)로 변경하여 모델을 훈련하였더니 RMSE가 50만이 넘게 뛰는 것을 확인할 수 있었습니다.<br/>
# 재건축의 년도가 최근일 수 록 건축 기술이 발전해서 그런 것 같다는 결론을 내렸습니다.<br/>
# 데이터를 0과 1로 압축하면서, 건축의 년도가 사라져 점수가 높아진 것 같습니다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### 실패 2

# %% [markdown]
# <p style= "font-size:16px; line-height:30px;">그 다음에는 boxplot으로 사분위보다 높은 수(저는 이 값들을 이상치로 판단하였습니다)를 출력하여 제거한 후 진행해보았는데, 마찬가지로 RMSE값이 높게 뛰었습니다.<br/>
# 저는 이상치로 판단을 했지만 사분위수를 넘은 수라고 해서 이상치는 아니었다는 것을 깨달았습니다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### 실패 3

# %% [markdown]
# <p style= "font-size:16px; line-height:30px;">이 다음으로 시도했던 것은 corr로 상관 계수를 출력해본 후 보통 ±0.2로는 상관관계가 거의 없다고 판단하므로 ±0.2 미만의 값들을 제거하여 진행했습니다.<br/> 조금이지만 마찬가지로 RMSE값이높아진 것을 확인할 수 있었으며, 값이 작더라도 모델의 훈련에 영향을 미친다는 것을 깨달았습니다.<br/>
# 'yr_renovated'가 그 예였는데, price에 대한 상관계수가 0.140808이었음에도 불구하고, 불 값으로 데이터를 처리하니 RMSE값이 엄청 뛰었습니다.</p>

# %% [markdown]
# <div style = "height: 25px;"></div>

# %% [markdown]
# ### 성공, 캣부스트

# %% [markdown]
# <p style= "font-size:16px; line-height:30px;">지금까지는 모두 LightGBM, XGBoost, GradientBoost를 앙상블하여 진행을 하였는데, <br/>
# 이 세 모델을 알아보던 중, CatBoost라는 모델을 알게 되었습니다.<br/>
# 데이터 전처리를 간단하게 하여 진행해본 결과, 예상대로 스케일값을 조정해주지 않아도 예측을 잘 하는 것을 확인하였고, 과적합이 되었을까 하는 걱정과는 다르게 다행히도, RMSE값이 110000미만으로 나왔습니다. <br/>
# 캣 부스트는 최근에 나온 라이브러리이지만, 다른 모델보다 우수하다라고는 말할 수 없다는 것이 신기했습니다. 캣부스트가 GBM의 단점을 개선하여 나온 알고리즘이지만, 결측치가 많거나, 변수 대부분이 실수이거나 등 경우에 따라서 GBM이 더 나을수도, CatBoost가 더 나을 수 있다는 것을 알게되었습니다.<br/>
# 앞으로는 섣부르게 어느 모델이 우수하다고 판단하지 말아야겠다고 생각했습니다.</p>
