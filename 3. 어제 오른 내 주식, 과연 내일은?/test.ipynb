# %% [markdown]
# # 목차
# <hr/>

# %% [markdown]
# <ol style = "font-size:20px; letter-spacing :0.1px;">
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 필요한 모듈 불러오기</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 함수</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">3. </span> MSFT (마이크로소프트)</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">4. </span> 인텔 (intel)</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">5. </span> 샤오미 (Xiaomi)</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">6. </span> 회고</i></li>
# </ol>

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## 세부 공통 목차
# <hr/>

# %% [markdown]
# > <ol>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 시계열 데이터 준비
# </i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 데이터 프레임 만들기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 데이터 확인하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> 데이터 시각화</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 각종 전처리 수행</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 결측치 처리</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 로그변환</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 3</span> : 시계열 안정성 분석</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> 시계열 분해 (Time Series Decomposition)기법 적용하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> Residual 안정성 확인</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 4</span> : 학습, 테스트 데이터셋 생성</i></li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 적정 ARIMA 모수 찾기</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> ACF, PACF 그려본 후 p, q값 구하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> 차분 안정성 확인 (d 구하기)</li>
#         </ul>
#     </li>
#     <li style = "margin-bottom:30px; list-style: none;"><i style = "font-weight:bold;font-style: normal;"><span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : ARIMA 모델 훈련과 테스트</i>
#         <ul style = "margin-top:10px; list-style:none;">
#             <li style = "margin-bottom:3px;"><span style = "font-weight:bold;color:#0172d4;">1. </span> ARIMA 모델 빌드와 훈련</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">2. </span> ARIMA 모델의 훈련 결과를 시각화하기</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> forecast() 메소드를 이용해 테스트 데이터 구간의 데이터를 예측</li>
#             <li style = "margin-bottom:5px;"><span style = "font-weight:bold;color:#0172d4;">3. </span> 최종 예측 모델 정확도 측정(MAPE)</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 1. 필요한 모듈 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import warnings
import math
from matplotlib.pylab import rcParams
from matplotlib import pyplot as plt
from statsmodels. tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
warnings.filterwarnings(action='ignore')

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 2. 함수

# %%
# 주어진 timeseries에 대한 Augmented Dickey-Fuller Test를 수행하는 코드
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 구간 통계치(Rolling Statistics)를 시각화해 보는 함수
def plot_rolling_statistics(timeseries, window = 12):
    # 이동평균 시계열
    rolmean = timeseries.rolling(window = window).mean()
    # 이동표준편차 시계열
    rolstd = timeseries.rolling(window = window).std()
    
    # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    oring = plt.plot(timeseries, color = "blue", label = "Original")
    mean = plt.plot(rolmean, color = "red", label = "Rolling Mean")
    std = plt.plot(rolstd, color = "black", label = "Rolling Std")
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block = False)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 3. MSFT (마이크로소프트)
# <hr/>

# %% [markdown]
# <img src = "img/logo_MSFT.png" style = "float:left; width:500px;">

# %% [markdown]
# <div style = "height: 45px;"><div/>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 시계열 데이터 준비

# %% [markdown]
# ## (1) 데이터프레임 만들기
# <hr/>

# %%
df = pd.read_csv('MSFT.csv', index_col = 'Date', parse_dates = True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-04-28  256.079987  256.540009  252.949997  254.559998  252.503250
# 2021-04-29  255.460007  256.100006  249.000000  252.509995  250.469818
# 2021-04-30  249.740005  253.080002  249.600006  252.179993  250.142471
# 2021-05-03  253.399994  254.350006  251.119995  251.860001  249.825058
# 2021-05-04  250.970001  251.210007  245.759995  247.789993  245.787949
# ...                ...         ...         ...         ...         ...
# 2022-04-21  288.579987  293.299988  280.059998  280.809998  280.809998
# 2022-04-22  281.679993  283.200012  273.380005  274.029999  274.029999
# 2022-04-25  273.290009  281.109985  270.769989  280.720001  280.720001
# 2022-04-26  277.500000  278.359985  270.000000  270.220001  270.220001
# 2022-04-27  282.100006  290.970001  279.160004  283.220001  283.220001
#
#               Volume
# Date
# 2021-04-28  46903100
# 2021-04-29  40589000
# 2021-04-30  30945100
# ...

# %%
# 종가(close) 데이터만 사용함
ts = df['Close']

# %%
ts.head()
# Out:
# Date
# 2021-04-28    254.559998
# 2021-04-29    252.509995
# 2021-04-30    252.179993
# 2021-05-03    251.860001
# 2021-05-04    247.789993
# Name: Close, dtype: float64

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 데이터 확인하기
# <hr/>

# %%
new_df = ts[:140]

# %%
ts_df = pd.DataFrame(ts)
ts_df
# Out:
#                  Close
# Date
# 2021-04-28  254.559998
# 2021-04-29  252.509995
# 2021-04-30  252.179993
# 2021-05-03  251.860001
# 2021-05-04  247.789993
# ...                ...
# 2022-04-21  280.809998
# 2022-04-22  274.029999
# 2022-04-25  280.720001
# 2022-04-26  270.220001
# 2022-04-27  283.220001
#
# [253 rows x 1 columns]

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) 데이터 시각화
# <hr/>

# %%
# matlab 차트의 기본 크기를 13, 6으로 지정
rcParams['figure.figsize'] = 13, 6 

# 시계열(time series) 데이터 차트로 확인하기
plt.plot(ts)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 각종 전처리 수행

# %% [markdown]
# ## (1) 결측치 처리
# <hr/>

# %% [markdown]
# ### 결측치 확인하기

# %%
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
ts.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 253 entries, 2021-04-28 to 2022-04-27
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 253 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
ts.isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 로그변환
# <hr/>

# %%
ts_log = np.log(ts)

# %%
# 로그 변환 전 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.807437
# p-value                          0.376776
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %%
# 로그 변환 후 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.821097
# p-value                          0.370039
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %% [markdown]
# <b style="color: blue;">로그함수로 변환하니 p-value가 약 0.006 떨어진 것을 확인할 수 있었다.</b>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 3</span> : 시계열 안정성 분석

# %% [markdown]
# ## (1) 시계열 분해 (Time Series Decomposition)기법 적용하기
# <hr/>

# %%
decomposition = seasonal_decompose(ts_log, period = 12)

trend = decomposition.trend # 추세(시간 추이에 따라 나타나는 평균값 변화 )
seasonal = decomposition.seasonal # 계절성(패턴이 파악되지 않은 주기적 변화)
residual = decomposition.resid # 원본(로그변환한) - 추세 - 계절성
plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) Residual 안정성 확인
# <hr/>

# %%
plt.rcParams["figure.figsize"] = (13, 6)
plot_rolling_statistics(residual)

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.446753e+00
# p-value                        1.704633e-13
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.330000e+02
# Critical Value (1%)           -3.458731e+00
# Critical Value (5%)           -2.874026e+00
# Critical Value (10%)          -2.573424e+00
# dtype: float64

# %% [markdown]
# seasonal_decompose 메서드를 통해 **trend**, **seasonality**를 **분리**해낸 결과,<br/> <b style="color: blue;">0.370039였던 p-value가 1.704633e-13으로 크게 줄었다.</b><br/>
# 이정도면 충분히 안정적인 시계열이라고 할 수 있으므로, 모델의 정확도를 높이기 위해 ARIMA 모델을 `residual`로 훈련시켜 예측하고자 한다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 4</span> : 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = residual[:int(len(residual)*0.9)], residual[int(len(residual)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, c='r', label='training dataset')  
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 적정 ARIMA 모수 찾기

# %% [markdown]
# ## (1) ACF, PACF 그려본 후 p, q값 구하기
# <hr/>

# %%
# ACF : Autocorrelation 그래프 그리기
plot_acf(residual)

# PACF : Partial Autocorrelation 그래프 그리기
plot_pacf(residual)  

plt.show()

# %% [markdown]
# 앞서 생성한 ARMA데이터에 대하여 ACFR, PACF를 그려보면 다음과 같다.<br/>
# ACF가 LAG가 **5**에서 절단점을 가지고(절단점-1= 4 = q)<br/>
# PACF 또한 LAG가 **9**(절단점 - 1 = 8 = p)이후에 절단점을 가진다.<br/>
# 따라서, <b style="color: red;">ARIMA모델의 모수는 (4, x, 8)</b>라고 추측해볼 수 있다.

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 차분 안정성 확인 (d 구하기)
# <hr/>

# %%
# 1차 차분 구하기
diff_1 = residual.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.693078e+00
# p-value                        3.991778e-14
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.270000e+02
# Critical Value (1%)           -3.459490e+00
# Critical Value (5%)           -2.874358e+00
# Critical Value (10%)          -2.573602e+00
# dtype: float64

# %%
# 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.699960e+00
# p-value                        1.078814e-16
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.240000e+02
# Critical Value (1%)           -3.459885e+00
# Critical Value (5%)           -2.874531e+00
# Critical Value (10%)          -2.573694e+00
# dtype: float64

# %%
# 3차 차분 구하기
diff_3 = diff_2.diff(periods=1).iloc[1:]
diff_3.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.699960e+00
# p-value                        1.078814e-16
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.240000e+02
# Critical Value (1%)           -3.459885e+00
# Critical Value (5%)           -2.874531e+00
# Critical Value (10%)          -2.573694e+00
# dtype: float64

# %% [markdown]
# 1차 차분을 했을 때 보다 <b style="color: blue;">2차 차분을 했을 때의 p값이 더 0에 가까우며</b>, 3차 차분 이상을 했을 때 값이 변하지 않는 것을 확인했다. <br/>
# 때문에 차분은 <b style="color: red;">2차 차분</b>을 하기로 판단하였으며 <b style="color: red;">b의 값은 2</b>로 지정했다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : ARIMA 모델 훈련과 테스트

# %% [markdown]
# ## (1) ARIMA 모델 빌드와 훈련
# <hr/>

# %%
model = ARIMA(train_data, order=(4, 2, 8))

# %%
fitted_m = model.fit()

# %%
print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  resid   No. Observations:                  216
# Model:                 ARIMA(4, 2, 8)   Log Likelihood                 633.421
# Date:                Sat, 30 Apr 2022   AIC                          -1240.842
# Time:                        18:11:35   BIC                          -1197.084
# Sample:                             0   HQIC                         -1223.160
#                                 - 216
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6028      0.469     -3.416      0.001      -2.522      -0.683
# ar.L2         -1.5730      0.351     -4.477      0.000      -2.262      -0.884
# ar.L3         -1.4965      0.406     -3.686      0.000      -2.292      -0.701
# ...

# %% [markdown]
# #### summary 출력 결과 해석
# - coef값은 0에서 가장 떨어졌을 때 가장 이상적이며, p값은 0과 가장 가까울 때 좋다.

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) ARIMA 모델의 훈련 결과를 시각화하기

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])

plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) forecast() 메소드를 이용해 테스트 데이터 구간의 데이터를 예측

# %%
fitted_m = model.fit() 

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(9,5), dpi=100)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, label='training')  
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (4) 최종 예측 모델 정확도 측정(MAPE)

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0005459942530045775
# MAE:  0.019903904743350288
# RMSE:  0.023366519916422676
# MAPE: 1.97%

# %% [markdown]
# 최종적인 예측 모델의 정확도(MAPE)는 1.97%로 높은 정확도를 보였다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 4. 인텔(intel)
# <hr/>

# %% [markdown]
# <img src = "img/logo_intel.png" style = "float:left; height:115px;">

# %% [markdown]
# <div style = "height: 40px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 시계열 데이터 준비

# %% [markdown]
# ## (1) 데이터프레임 만들기
# <hr/>

# %%
df = pd.read_csv('INTC.csv', index_col = 'Date', parse_dates = True)

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-04-29  57.880001  58.299999  57.470001  58.279999  56.719757  23290600
# 2021-04-30  57.610001  58.430000  57.070000  57.529999  55.989834  30731800
# 2021-05-03  57.860001  57.880001  56.840000  57.259998  55.727058  22281700
# 2021-05-04  56.880001  56.980000  55.810001  56.900002  55.376701  35323600
# 2021-05-05  56.959999  57.299999  56.459999  56.849998  55.328037  21001900
# ...               ...        ...        ...        ...        ...       ...
# 2022-04-22  47.450001  47.650002  46.500000  46.540001  46.540001  28204700
# 2022-04-25  46.209999  47.139999  46.180000  47.060001  47.060001  35999300
# 2022-04-26  46.689999  46.840000  45.509998  45.520000  45.520000  35356600
# 2022-04-27  45.480000  46.060001  45.009998  45.220001  45.220001  28320900
# 2022-04-28  45.790001  47.270000  45.540001  46.840000  46.840000  38264000
#
# [253 rows x 6 columns]

# %%
# 종가(close) 데이터만 사용함
ts = df['Close']

# %%
ts.head()
# Out:
# Date
# 2021-04-29    58.279999
# 2021-04-30    57.529999
# 2021-05-03    57.259998
# 2021-05-04    56.900002
# 2021-05-05    56.849998
# Name: Close, dtype: float64

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 데이터 확인하기
# <hr/>

# %%
new_df = ts[:140]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4654/3797513279.py in <module>
# ----> 1 new_df = ts[:140]
#
# NameError: name 'ts' is not defined

# %%
ts_df = pd.DataFrame(ts)
ts_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4654/3682439126.py in <module>
# ----> 1 ts_df = pd.DataFrame(ts)
#       2 ts_df
#
# NameError: name 'ts' is not defined

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) 데이터 시각화
# <hr/>

# %%
# matlab 차트의 기본 크기를 13, 6으로 지정
rcParams['figure.figsize'] = 13, 6 

# 시계열(time series) 데이터 차트로 확인하기
plt.plot(ts)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 각종 전처리 수행

# %% [markdown]
# ## (1) 결측치 처리
# <hr/>

# %% [markdown]
# ### 결측치 확인하기

# %%
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
ts.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 253 entries, 2021-04-29 to 2022-04-28
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 253 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
ts.isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 로그변환
# <hr/>

# %%
ts_log = np.log(ts)

# %%
# 로그 변환 전 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.226080
# p-value                          0.196917
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %%
# 로그 변환 후 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.200070
# p-value                          0.206220
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %% [markdown]
# <b style="color: blue;">로그함수로 변환하니 p-value가 0.196917에서 0.206220으로 오히려 올라간 것을 확인할 수 있었다.</b>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 3</span> : 시계열 안정성 분석

# %% [markdown]
# ## (1) 시계열 분해 (Time Series Decomposition)기법 적용하기
# <hr/>

# %%
decomposition = seasonal_decompose(ts_log, period = 12)

trend = decomposition.trend # 추세(시간 추이에 따라 나타나는 평균값 변화 )
seasonal = decomposition.seasonal # 계절성(패턴이 파악되지 않은 주기적 변화)
residual = decomposition.resid # 원본(로그변환한) - 추세 - 계절성
plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) Residual 안정성 확인
# <hr/>

# %%
plt.rcParams["figure.figsize"] = (13, 6)
plot_rolling_statistics(residual)

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.802377e+00
# p-value                        2.220233e-09
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.260000e+02
# Critical Value (1%)           -3.459620e+00
# Critical Value (5%)           -2.874415e+00
# Critical Value (10%)          -2.573632e+00
# dtype: float64

# %% [markdown]
# seasonal_decompose 메서드를 통해 **trend**, **seasonality**를 **분리**해낸 결과,<br/> <b style="color: blue;">0.206220이었던 p-value가 2.220233e-09로 크게 줄었다.</b><br/>
# 이정도면 충분히 안정적인 시계열이라고 할 수 있으므로, 모델의 정확도를 높이기 위해 ARIMA 모델을 `residual`로 훈련시켜 예측하고자 한다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 4</span> : 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = residual[:int(len(residual)*0.9)], residual[int(len(residual)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, c='r', label='training dataset')  
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 적정 ARIMA 모수 찾기

# %% [markdown]
# ## (1) ACF, PACF 그려본 후 p, q값 구하기
# <hr/>

# %%
# ACF : Autocorrelation 그래프 그리기
plot_acf(residual)

# PACF : Partial Autocorrelation 그래프 그리기
plot_pacf(residual)  

plt.show()

# %% [markdown]
# 앞서 생성한 ARMA데이터에 대하여 ACFR, PACF를 그려보면 다음과 같다.<br/>
# ACF가 LAG가 **9**에서 절단점을 가지고(절단점-1= 8 = q)<br/>
# PACF 또한 LAG가 **16**(절단점 - 1 = 15 = p)이후에 절단점을 가진다.<br/>
# 따라서, <b style="color: red;">ARIMA모델의 모수는 (8, x, 15)</b>라고 추측해볼 수 있다.

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 차분 안정성 확인 (d 구하기)
# <hr/>

# %%
# 1차 차분 구하기
diff_1 = residual.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.068615e+00
# p-value                        1.571482e-12
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.240000e+02
# Critical Value (1%)           -3.459885e+00
# Critical Value (5%)           -2.874531e+00
# Critical Value (10%)          -2.573694e+00
# dtype: float64

# %%
# 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.323875e+00
# p-value                        3.512986e-13
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.230000e+02
# Critical Value (1%)           -3.460019e+00
# Critical Value (5%)           -2.874590e+00
# Critical Value (10%)          -2.573725e+00
# dtype: float64

# %%
# 3차 차분 구하기
diff_3 = diff_2.diff(periods=1).iloc[1:]
diff_3.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.323875e+00
# p-value                        3.512986e-13
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.230000e+02
# Critical Value (1%)           -3.460019e+00
# Critical Value (5%)           -2.874590e+00
# Critical Value (10%)          -2.573725e+00
# dtype: float64

# %% [markdown]
# 1차 차분을 했을 때 보다 <b style="color: blue;">2차 차분을 했을 때의 p값이 더 0에 가까우며</b>, 3차 차분 이상을 했을 때 값이 변하지 않는 것을 확인했다. <br/>
# 때문에 차분은 <b style="color: red;">2차 차분</b>을 하기로 판단하였으며 <b style="color: red;">b의 값은 2</b>로 지정했다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : ARIMA 모델 훈련과 테스트

# %% [markdown]
# ## (1) ARIMA 모델 빌드와 훈련
# <hr/>

# %%
model = ARIMA(train_data, order=(8, 2, 15))

# %%
fitted_m = model.fit()

# %%
print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  resid   No. Observations:                  216
# Model:                ARIMA(8, 2, 15)   Log Likelihood                 594.558
# Date:                Sat, 30 Apr 2022   AIC                          -1141.117
# Time:                        18:11:39   BIC                          -1060.333
# Sample:                             0   HQIC                         -1108.473
#                                 - 216
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6246      1.202     -1.352      0.176      -3.980       0.731
# ar.L2         -2.0304      2.022     -1.004      0.315      -5.994       1.933
# ar.L3         -2.1265      2.275     -0.935      0.350      -6.586       2.333
# ...

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) ARIMA 모델의 훈련 결과를 시각화하기

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])

plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) forecast() 메소드를 이용해 테스트 데이터 구간의 데이터를 예측

# %%
fitted_m = model.fit() 

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (4) 최종 예측 모델 정확도 측정(MAPE)

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0008767282541052347
# MAE:  0.021721834518804956
# RMSE:  0.029609597331021486
# MAPE: 2.12%

# %% [markdown]
# 최종적인 예측 모델의 정확도(MAPE)는 2.12%로 높은 정확도를 보였다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # 5. 샤오미 (Xiaomi)
# <hr/>

# %% [markdown]
# <img src = "img/logo_xiaomi.png" style = "float:left; height:115px;">

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 1</span> : 시계열 데이터 준비

# %% [markdown]
# ## (1) 데이터프레임 만들기
# <hr/>

# %%
df = pd.read_csv('XIACY.csv', index_col = 'Date', parse_dates = True)

# %%
df
# Out:
#               Open   High     Low   Close  Adj Close  Volume
# Date
# 2021-04-30  14.700  14.70  14.700  14.700     14.700       0
# 2021-05-03  14.700  14.70  14.700  14.700     14.700       0
# 2021-05-04  14.700  14.70  14.700  14.700     14.700       0
# 2021-05-05  14.700  14.70  14.700  14.700     14.700       0
# 2021-05-06  14.700  14.70  14.700  14.700     14.700       0
# ...            ...    ...     ...     ...        ...     ...
# 2022-04-25   7.000   7.10   6.960   7.055      7.055   15991
# 2022-04-26   6.830   6.84   6.761   6.780      6.780   16092
# 2022-04-27   7.060   7.27   7.060   7.110      7.110  123720
# 2022-04-28   7.120   7.20   7.080   7.100      7.100    3805
# 2022-04-29   7.681   7.74   7.540   7.540      7.540  111036
#
# [253 rows x 6 columns]

# %%
# 종가(close) 데이터만 사용함
ts = df['Close']

# %%
ts.head()
# Out:
# Date
# 2021-04-30    14.7
# 2021-05-03    14.7
# 2021-05-04    14.7
# 2021-05-05    14.7
# 2021-05-06    14.7
# Name: Close, dtype: float64

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 데이터 확인하기
# <hr/>

# %%
new_df = ts[:140]

# %%
ts_df = pd.DataFrame(ts)
ts_df
# Out:
#              Close
# Date
# 2021-04-30  14.700
# 2021-05-03  14.700
# 2021-05-04  14.700
# 2021-05-05  14.700
# 2021-05-06  14.700
# ...            ...
# 2022-04-25   7.055
# 2022-04-26   6.780
# 2022-04-27   7.110
# 2022-04-28   7.100
# 2022-04-29   7.540
#
# [253 rows x 1 columns]

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) 데이터 시각화
# <hr/>

# %%
# matlab 차트의 기본 크기를 13, 6으로 지정
rcParams['figure.figsize'] = 13, 6 

# 시계열(time series) 데이터 차트로 확인하기
plt.plot(ts)

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 2</span> : 각종 전처리 수행

# %% [markdown]
# ## (1) 결측치 처리
# <hr/>

# %% [markdown]
# ### 결측치 확인하기

# %%
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
ts.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 253 entries, 2021-04-30 to 2022-04-29
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 253 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
ts.isnull().sum()
# Out:
# 0

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 로그변환
# <hr/>

# %%
ts_log = np.log(ts)

# %%
# 로그 변환 전 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.181457
# p-value                          0.940696
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %%
# 로그 변환 후 Augmented Dickey-Fuller Test 수행
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.667684
# p-value                          0.989170
# #Lags Used                       6.000000
# Number of Observations Used    246.000000
# Critical Value (1%)             -3.457215
# Critical Value (5%)             -2.873362
# Critical Value (10%)            -2.573070
# dtype: float64

# %% [markdown]
# <b style="color: blue;">로그함수로 변환하니 p-value가 0.940696에서 0.989170으로 오히려 올라간 것을 확인할 수 있었다.</b>

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 3</span> : 시계열 안정성 분석

# %% [markdown]
# ## (1) 시계열 분해 (Time Series Decomposition)기법 적용하기
# <hr/>

# %%
decomposition = seasonal_decompose(ts_log, period = 12)

trend = decomposition.trend # 추세(시간 추이에 따라 나타나는 평균값 변화 )
seasonal = decomposition.seasonal # 계절성(패턴이 파악되지 않은 주기적 변화)
residual = decomposition.resid # 원본(로그변환한) - 추세 - 계절성
plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) Residual 안정성 확인
# <hr/>

# %%
plt.rcParams["figure.figsize"] = (13, 6)
plot_rolling_statistics(residual)

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.653332e+00
# p-value                        9.747062e-07
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.250000e+02
# Critical Value (1%)           -3.459752e+00
# Critical Value (5%)           -2.874473e+00
# Critical Value (10%)          -2.573663e+00
# dtype: float64

# %% [markdown]
# seasonal_decompose 메서드를 통해 **trend**, **seasonality**를 **분리**해낸 결과,<br/> <b style="color: blue;">0.989170이었던 p-value가 9.747062e-07로 크게 줄었다.</b><br/>
# 이정도면 충분히 안정적인 시계열이라고 할 수 있으므로, 모델의 정확도를 높이기 위해 ARIMA 모델을 `residual`로 훈련시켜 예측하고자 한다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 4</span> : 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = residual[:int(len(residual)*0.9)], residual[int(len(residual)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, c='r', label='training dataset')  
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 5</span> : 적정 ARIMA 모수 찾기

# %% [markdown]
# ## (1) ACF, PACF 그려본 후 p, q값 구하기
# <hr/>

# %%
# ACF : Autocorrelation 그래프 그리기
plot_acf(residual)

# PACF : Partial Autocorrelation 그래프 그리기
plot_pacf(residual)  

plt.show()

# %% [markdown]
# 앞서 생성한 ARMA데이터에 대하여 ACFR, PACF를 그려보면 다음과 같다.<br/>
# ACF가 LAG가 **16**에서 절단점을 가지고(절단점-1= 15 = q)<br/>
# PACF 또한 LAG가 **21**(절단점 - 1 = 20 = p)이후에 절단점을 가진다.<br/>
# 따라서, <b style="color: red;">ARIMA모델의 모수는 (15, x, 20)</b>라고 추측해볼 수 있다.

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) 차분 안정성 확인 (d 구하기)
# <hr/>

# %%
# 1차 차분 구하기
diff_1 = residual.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.646349e+00
# p-value                        1.838290e-11
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.240000e+02
# Critical Value (1%)           -3.459885e+00
# Critical Value (5%)           -2.874531e+00
# Critical Value (10%)          -2.573694e+00
# dtype: float64

# %%
# 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.793082e+00
# p-value                        2.213432e-14
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.230000e+02
# Critical Value (1%)           -3.460019e+00
# Critical Value (5%)           -2.874590e+00
# Critical Value (10%)          -2.573725e+00
# dtype: float64

# %%
# 3차 차분 구하기
diff_3 = diff_2.diff(periods=1).iloc[1:]
diff_3.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.793082e+00
# p-value                        2.213432e-14
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.230000e+02
# Critical Value (1%)           -3.460019e+00
# Critical Value (5%)           -2.874590e+00
# Critical Value (10%)          -2.573725e+00
# dtype: float64

# %% [markdown]
# 1차 차분을 했을 때 보다 <b style="color: blue;">2차 차분을 했을 때의 p값이 더 0에 가까우며</b>, 3차 차분 이상을 했을 때 값이 변하지 않는 것을 확인했다. <br/>
# 때문에 차분은 <b style="color: red;">2차 차분</b>을 하기로 판단하였으며 <b style="color: red;">b의 값은 2</b>로 지정했다.

# %% [markdown]
# <div style = "height: 50px;"></div>

# %% [markdown]
# # <span style = "font-weight:bold;color:#0172d4;">STEP 6</span> : ARIMA 모델 훈련과 테스트

# %% [markdown]
# ## (1) ARIMA 모델 빌드와 훈련
# <hr/>

# %%
model = ARIMA(train_data, order=(15, 2, 20))

# %%
fitted_m = model.fit()

# %%
print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  resid   No. Observations:                  216
# Model:               ARIMA(15, 2, 20)   Log Likelihood                 497.785
# Date:                Sat, 30 Apr 2022   AIC                           -923.571
# Time:                        18:11:46   BIC                           -802.396
# Sample:                             0   HQIC                          -874.605
#                                 - 216
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5532      1.064     -1.460      0.144      -3.639       0.532
# ar.L2         -2.1006      0.865     -2.428      0.015      -3.796      -0.405
# ar.L3         -2.3452      1.578     -1.487      0.137      -5.437       0.747
# ...

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (2) ARIMA 모델의 훈련 결과를 시각화하기

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])

plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (3) forecast() 메소드를 이용해 테스트 데이터 구간의 데이터를 예측

# %%
fitted_m = model.fit() 

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(9,5), dpi=100)
# train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 residual을 선택
plt.plot(residual, label='training')  
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# <div style = "height: 15px;"></div>

# %% [markdown]
# ## (4) 최종 예측 모델 정확도 측정(MAPE)

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0008177398002577123
# MAE:  0.025382499627019647
# RMSE:  0.028596150095033985
# MAPE: 2.51%

# %% [markdown]
# 최종적인 예측 모델의 정확도(MAPE)는 2.51%로 높은 정확도를 보였다.

# %% [markdown]
# # 6. 회고
# <hr/>

# %% [markdown]
# 처음에는 수식과 그래프가 너무 많아서 어렵게 느껴졌습니다.
# 때문에 처음에는 lms의 함수와 코드들을 복사하여 붙여넣기하는 식으로 진행했는데, <br/>
# 이렇게 진행하다보니 오류가 뜰 때마다 왜 오류가 떳는지, 그래프를 어떻게 해석하는지 몰랐습니다.<br/>
#
# 그래서 모두 지운 후 모르는 부분은 검색하며 알아가면서 처음부터 코드를 짰습니다.<br/>
# 그 중 ARIMA의 정확한 모수를 구하는 데에 있어 어려움을 많이 느꼈는데, 왜 lms에서는 모수가 14, 1, 0이 나왔는지 이해가 되지 않았기 때문입니다.<br/>
#
# 찾아본 결과로는 그래프를 해석할 때, 어느 지점 부터 구간(그래프의 파란 범위)안에 들어가는지를 파악하고, 그 지점을 절단점이라 하며 절단점-1이 모수인 것을 알아내었습니다.<br/>
# 또한 ACF가 점진적으로 0을 향해 줄어들면 데이터 시계열이 불안정한 것이므로, 안정적인 시계열로 바꿔준 뒤에 ACF를 다시 그려 모수를 구해주었습니다.<br/>
#
# 이렇게 모수를 정확하게 바꿔준 결과, 일직선이었던 구간 예측 그래프의 모양이 바뀌었습니다.<br/> MAPE가 잘 나왔으나, 이 부분에 대해서 계속 의문을 가졌는데, 의문이 해소되어서 재미있었습니다.
